# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# %%
from JunturaPN import JunturaPN

juntura = JunturaPN()

juntura['T'] = 300      # K
juntura['ni'] = 10**10   # cm^-3  (Silicio)
juntura['NA'] = 10**14    # cm^-3
juntura['ND'] = 5*10**13
juntura['er'] = 11.8
juntura['V'] = 0.1


juntura['W']

# 1e14 - 10**14
# juntura.function('ro_x')

juntura.plot('ro_x')
juntura.plot('E_x')
juntura.plot('V_x')
# Out:
# lambdify:  Piecewise((-1.6e-5, (x >= -0.000124931704325134) & (x <= 0)), (8.0e-6, (x <= 0.000249863408650269) & (x > 0)), (0, True))
# lambdify:  Piecewise((-22981901.75237*Min(0, x) + 7660633.91745667*Min(0.000249863408650269, x) - 1914.11210303758, x > -0.000124931704325134), (0, True))
# lambdify:  -Piecewise((0, x <= -0.000124931704325134), (Piecewise((4.54747350886464e-13*x - 11490950.876185*Min(0, x)**2 + 3830316.95872833*Min(0.000249863408650269, x)**2 - 1914.11210303758*Min(0.000249863408650269, x) - 0.119566643650926, x > -0.000124931704325134), (-7660633.91745667*x**2 - 1914.11210303758*x - 0.119566643650926, True)), True))
